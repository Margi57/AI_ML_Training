# %%
from google.colab import drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/practice/netflix_titles.csv", encoding="latin-1")
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
# 8807   s8808  TV Show     Parasyte: The Grey     Yeon Sang-ho
# 8808   s8809    Movie                 Serena     Susanne Bier
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8809 entries, 0 to 8808
# Data columns (total 26 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8809 non-null   object
#  1   type          8809 non-null   object
#  2   title         8809 non-null   object
#  3   director      6175 non-null   object
#  4   cast          7984 non-null   object
#  5   country       7978 non-null   object
#  6   date_added    8799 non-null   object
#  7   release_year  8809 non-null   int64
#  8   rating        8805 non-null   object
#  9   duration      8806 non-null   object
#  10  listed_in     8809 non-null   object
#  11  description   8809 non-null   object
#  12  Unnamed: 12   0 non-null      float64
#  13  Unnamed: 13   0 non-null      float64
#  14  Unnamed: 14   0 non-null      float64
#  15  Unnamed: 15   0 non-null      float64
#  16  Unnamed: 16   0 non-null      float64
#  17  Unnamed: 17   0 non-null      float64
# ...

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# Unnamed: 12     8809
# Unnamed: 13     8809
# Unnamed: 14     8809
# Unnamed: 15     8809
# Unnamed: 16     8809
# Unnamed: 17     8809
# Unnamed: 18     8809
# Unnamed: 19     8809
# Unnamed: 20     8809
# Unnamed: 21     8809
# Unnamed: 22     8809
# Unnamed: 23     8809
# Unnamed: 24     8809
# Unnamed: 25     8809
# dtype: int64

# %%
df.drop(columns=['Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21','Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25'],inplace=True)
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
# 8807   s8808  TV Show     Parasyte: The Grey     Yeon Sang-ho
# 8808   s8809    Movie                 Serena     Susanne Bier
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.shape
# Out:
# (8809, 12)

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()/(len(df))*100
# Out:
# show_id          0.000000
# type             0.000000
# title            0.000000
# director        29.901237
# cast             9.365422
# country          9.433534
# date_added       0.113520
# release_year     0.000000
# rating           0.045408
# duration         0.034056
# listed_in        0.000000
# description      0.000000
# dtype: float64

# %%
#EDA
cat_cols=df.select_dtypes(include=['object']).columns
num_cols = df.select_dtypes(include=np.number).columns.tolist()
print("Categorical Variables:")
print(cat_cols)
print("Numerical Variables:")
print(num_cols)
# Out:
# Categorical Variables:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')
# Numerical Variables:
# ['release_year']

# %%
# !pip install warning
import seaborn as sns
import matplotlib.pyplot as plt

# import warning
# # warning.filterwarning
# warning.filterwarnings('ignore')
for i in df.select_dtypes(include="number").columns:
  sns.histplot(data=df,x=i)
  plt.show()
# Out:
# ERROR: Could not find a version that satisfies the requirement warning (from versions: none)
# ERROR: No matching distribution found for warning

# %%
for i in df.select_dtypes(include="number").columns:
  sns.boxplot(data=df,x=i)
  plt.show()

# %%
for i in df.select_dtypes(include="object").columns:
  sns.histplot(data=df,x=i)
  plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-111-df250d85064b> in <cell line: 1>()
#       1 for i in df.select_dtypes(include="object").columns:
# ----> 2   sns.histplot(data=df,x=i)
#       3   plt.show()
#
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1414     if p.univariate:
#    1415
# -> 1416         p.plot_univariate_histogram(
#    1417             multiple=multiple,
#    1418             element=element,
#
# ...

# %%
# !pip install --upgrade seaborn

# %%
import seaborn as sns

for i in df.select_dtypes(include="object").columns:
    sns.boxplot(data=df, x=i)
    plt.show()

# %%
# null object colums to replace into frequent count
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='most_frequent')

for i in df.select_dtypes(include="object").columns:
    df[i] = imputer.fit_transform(df[[i]])[:, 0]

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water    Rajiv Chilaka
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans    Rajiv Chilaka
# 4         s5  TV Show           Kota Factory    Rajiv Chilaka
# ...      ...      ...                    ...              ...
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
# 8807   s8808  TV Show     Parasyte: The Grey     Yeon Sang-ho
# 8808   s8809    Movie                 Serena     Susanne Bier
#
#                                                    cast        country  \
# 0                                    David Attenborough  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
def outlier_df(col):
  q1,q3=np.percentile(col,[25,75])
  iqr=q3-q1
  lw=q1-1.5*iqr
  uw=q3+1.5*iqr
  return lw,uw

# %%
for i in ["release_year"]:
  lw,uw=outlier_df(df[i])
  df[i]=np.where(df[i]<lw,lw,df[i])
  df[i]=np.where(df[i]>uw,uw,df[i])
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water    Rajiv Chilaka
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans    Rajiv Chilaka
# 4         s5  TV Show           Kota Factory    Rajiv Chilaka
# ...      ...      ...                    ...              ...
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
# 8807   s8808  TV Show     Parasyte: The Grey     Yeon Sang-ho
# 8808   s8809    Movie                 Serena     Susanne Bier
#
#                                                    cast        country  \
# 0                                    David Attenborough  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water    Rajiv Chilaka
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans    Rajiv Chilaka
# 4         s5  TV Show           Kota Factory    Rajiv Chilaka
# ...      ...      ...                    ...              ...
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
# 8807   s8808  TV Show     Parasyte: The Grey     Yeon Sang-ho
# 8808   s8809    Movie                 Serena     Susanne Bier
#
#                                                    cast        country  \
# 0                                    David Attenborough  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
#without outlier numerical data
for i in df.select_dtypes(include="number").columns:
  sns.boxplot(data=df,x=i)
  plt.show()

# %%
df['release_year']=df['release_year'].astype(int)
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water    Rajiv Chilaka
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans    Rajiv Chilaka
# 4         s5  TV Show           Kota Factory    Rajiv Chilaka
# ...      ...      ...                    ...              ...
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
# 8807   s8808  TV Show     Parasyte: The Grey     Yeon Sang-ho
# 8808   s8809    Movie                 Serena     Susanne Bier
#
#                                                    cast        country  \
# 0                                    David Attenborough  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
release_year=df['release_year']

# %%
release_year_count = df['release_year'].value_counts()

# Print the release years and their counts
print(release_year_count.index.tolist())
print(release_year_count)

# Create the pie chart
fig = plt.figure(figsize=(5, 5))
plt.pie(release_year_count, labels=release_year_count.index.tolist())
plt.title('release_year')
plt.show()
# Out:
# [2018, 2017, 2019, 2020, 2016, 2004, 2021, 2015, 2014, 2013, 2012, 2010, 2011, 2009, 2008, 2006, 2007, 2005, 2024]
# release_year
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
# 2004     783
# 2021     592
# 2015     560
# 2014     353
# 2013     288
# 2012     237
# 2010     194
# 2011     185
# 2009     152
# 2008     136
# 2006      96
# 2007      88
# 2005      80
# 2024       1
# Name: count, dtype: int64

# %%
rating=df['rating']
rating
# Out:
# 0       PG-13
# 1       TV-MA
# 2       TV-MA
# 3       TV-MA
# 4       TV-MA
#         ...
# 8804        R
# 8805       PG
# 8806    TV-14
# 8807    TV-MA
# 8808        A
# Name: rating, Length: 8809, dtype: object

# %%
tv_show_index = df[df['type'] == 'TV Show'].index
filtered_df = df.drop(tv_show_index)
filtered_df
new_df = filtered_df[['type', 'duration']]

new_df['duration']=new_df['duration'].str.replace('min','')

new_df.info()
# fig = plt.figure(figsize = (10, 5))

# # creating the bar plot
# plt.bar(df_type, df_duration, color ='maroon',
#         width = 0.4)
# plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6132 entries, 0 to 8808
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   type      6132 non-null   object
#  1   duration  6132 non-null   object
# dtypes: object(2)
# memory usage: 143.7+ KB
# <ipython-input-121-9f4840f4bd76>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['duration']=new_df['duration'].str.replace('min','')

# %%
filtered_df = df[df['type'] != 'TV Show']
new_df = filtered_df[['type', 'duration']]
new_df['duration'] = pd.to_numeric(new_df['duration'].str.replace('min', ''), errors='coerce')
print(new_df)
# fig = plt.figure(figsize = (10, 5))

# # creating the bar plot
# plt.bar(new_df['type'],new_df['duration'], color ='maroon', width = 0.4)
# plt.show()
# Out:
#        type  duration
# 0     Movie      90.0
# 6     Movie      91.0
# 7     Movie     125.0
# 9     Movie     104.0
# 12    Movie     127.0
# ...     ...       ...
# 8802  Movie     158.0
# 8804  Movie      88.0
# 8805  Movie      88.0
# 8806  Movie     111.0
# 8808  Movie     110.0
#
# [6132 rows x 2 columns]
# <ipython-input-122-e0ba5eee5d6e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['duration'] = pd.to_numeric(new_df['duration'].str.replace('min', ''), errors='coerce')

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()

df['rating']=labelencoder.fit_transform(df['rating'])
df['rating']
# Out:
# 0        8
# 1       12
# 2       12
# 3       12
# 4       12
#         ..
# 8804     9
# 8805     7
# 8806    10
# 8807    12
# 8808     3
# Name: rating, Length: 8809, dtype: int64

# %%
rating_count = df['rating'].value_counts()

# Print the release years and their counts
print(rating_count.index.tolist())
print(rating_count)

# Create the pie chart
fig = plt.figure(figsize=(5, 5))
plt.pie(rating_count, labels=rating_count.index.tolist())
plt.title("rating")
plt.show()
# Out:
# [12, 10, 13, 9, 8, 15, 14, 7, 11, 6, 4, 16, 5, 17, 1, 2, 0, 3]
# rating
# 12    3212
# 10    2160
# 13     863
# 9      799
# 8      490
# 15     334
# 14     307
# 7      287
# 11     220
# 6       80
# 4       41
# 16       6
# 5        3
# 17       3
# 1        1
# 2        1
# 0        1
# 3        1
# Name: count, dtype: int64

# %%
title=df['title'].head(50)
rating=df['rating'].head(50)
# creating the bar plot
fig = plt.figure(figsize = (10, 5))
plt.bar(title, rating, color ='maroon',
        width = 0.4)
plt.show()

# %%
dftitle=df['title'].head(50)
dfrating=df['rating'].head(50).astype(float)
dfduration=new_df['duration'].head(50)
print(dftitle)
print(dfrating)
print(dfduration)
# Out:
# 0                                  Dick Johnson Is Dead
# 1                                         Blood & Water
# 2                                             Ganglands
# 3                                 Jailbirds New Orleans
# 4                                          Kota Factory
# 5                                         Midnight Mass
# 6                      My Little Pony: A New Generation
# 7                                               Sankofa
# 8                         The Great British Baking Show
# 9                                          The Starling
# 10                  Vendetta: Truth, Lies and The Mafia
# 11                                     Bangkok Breaking
# 12                                         Je Suis Karl
# 13                     Confessions of an Invisible Girl
# 14                      Crime Stories: India Detectives
# 15                                    Dear White People
# 16    Europe's Most Dangerous Man: Otto Skorzeny in ...
# ...

# %%
dfduration = new_df['duration'].head(50).astype(int)

indices = dfduration.index
# print(new_df.columns)
print(indices)

column1_data = df.loc[indices, 'title']
column2_data = df.loc[indices, 'rating']
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %%
data = {
    'title': column1_data,
    'rating': column2_data,
    'duration':dfduration
}
n1 = pd.DataFrame(data)
n1
# Out:
#                                                 title  rating  duration
# 0                                Dick Johnson Is Dead       8        90
# 1                                       Blood & Water      12        91
# 2                                           Ganglands      12       125
# 3                               Jailbirds New Orleans      12       104
# 4                                        Kota Factory      12       127
# 5                                       Midnight Mass      12        91
# 6                    My Little Pony: A New Generation       7        67
# 7                                             Sankofa      12        94
# 8                       The Great British Baking Show      10       161
# 9                                        The Starling       8        61
# 10                Vendetta: Truth, Lies and The Mafia      12       166
# 11                                   Bangkok Breaking      12       147
# ...

# %%
title=n1['title']
rating=n1['rating']
duration=n1['duration']
plt.scatter(rating, duration, cmap='viridis', alpha=0.5)
for i, txt in enumerate(title):
    plt.annotate(txt, (rating[i], duration[i]),fontsize=5)

plt.xlabel("Rating")
plt.ylabel("Duration")

plt.show()
# Out:
# <ipython-input-148-0d3419119c53>:3: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(rating, duration, cmap='viridis', alpha=0.5)
